# %%
var('x y')
eq1 = (x-2*x*y == 0)
eq2 = ((x^2)/2-y == 0)
solve([eq1,eq2],x,y)
# Out:
# [[x == 0, y == 0], [x == -1, y == (1/2)], [x == 1, y == (1/2)]]

# %%
f = (x-2*x*y,(x^2)/2-y)
J = jacobian(f,(x,y))

# %%
J.subs(x=0,y=0).eigenvalues()
# Out:
# [-1, 1]

# %%
J.subs(x=-1,y=(1/2)).eigenvalues()
# Out:
# [-1/2*I*sqrt(7) - 1/2, 1/2*I*sqrt(7) - 1/2]

# %%
J.subs(x=1,y=(1/2)).eigenvalues()
# Out:
# [-1/2*I*sqrt(7) - 1/2, 1/2*I*sqrt(7) - 1/2]

# %%
plot_vector_field(f,(x,-1.5,-0.5),(y,0,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
solve([y==0,-4*sin(x)==0],x,y)
# Out:
# [[x == pi*z1790, y == 0]]

# %%
f=(y,-4*sin(x))
jacobian(f,(x,y)).subs(x=0,y=0).eigenvalues()
# Out:
# [-2*I, 2*I]

# %%
H(x,y) = (y^2) - 8*cos(x)
contour_plot(H,(-0.05,0.05),(-0.05,0.05),fill=false,contours=30)
# Out:
# Graphics object consisting of 1 graphics primitive
